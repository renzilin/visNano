# %%
sampleID  = 'F36'
samtools  = '/home/amax/anaconda3/envs/biotools/bin/samtools'
fqPath    = '/media/amax/disk1/renzl/repos/Project_new-nanopore/data/rawdata/KF0105_S1_f.fastq'
bedPath   = '/media/amax/disk1/renzl/repos/Project_new-nanopore/nanoforenstr/repeat.config'
bamPath   = '/media/amax/disk1/renzl/repos/Project_new-nanopore/alignment/result/F36.bam'

# %%
from myLib.myFq import myFqVis
myFqVis(sampleID, fqPath)
# Out:
# Processing FASTQ: : 4351892it [01:45, 41152.84it/s]
# Plotting...

# %%
from myLib.myBam import myBamVis
myBamVis(sampleID, bamPath, samtools)
# Out:
# Reading SAM/BAM: 100%|██████████| 823248/823248 [00:01<00:00, 494977.89it/s]

# %%
from myLib.myBed import myBedVis
myBedVis(sampleID, bedPath, bamPath, samtools)
# Out:
# Prcessing region: : 24it [00:03,  7.05it/s]
